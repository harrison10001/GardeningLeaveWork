# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline 

xlsx = pd.ExcelFile('C:/Users/mikeh/OneDrive/Documents/Mike/PythonStudy/QuantModel_Tester.xlsx')
df = pd.read_excel(xlsx, sheet_name = 'Index')

# %%
with pd.ExcelFile('C:/Users/mikeh/OneDrive/Documents/Mike/PythonStudy/QuantModel_Tester.xlsx') as xlsx:
    df_1 = pd.read_excel(xlsx, sheet_name = 'Index')
    df_2 = pd.read_excel(xlsx, sheet_name = 'DY')

# %%
data = {}

with pd.ExcelFile('C:/Users/mikeh/OneDrive/Documents/Mike/PythonStudy/QuantModel_Tester.xlsx') as xlsx:
    data['Index'] = pd.read_excel(xlsx, 'Index', index_col=None, na_values=['-'])
    data['DY'] = pd.read_excel(xlsx, 'DY', index_col=None, na_values=['-'])

# equivalent using the read_excel function...a list of sheet names can be passed to read_excel
# data = pd.read_excel('path_to_file.xls', ['Sheet1', 'Sheet2'],index_col=None, na_values=['NA'])


data
# Out:
# {'Index':    1980-01-31 1980-02-29 1980-03-31 1980-04-30 1980-05-31 1980-06-30  \
#  0           i        aat        aay        aaf        aae        aag
#  1         aab         ac       aaai          v       aaak        aan
#  2        aaau       aaao       aaac          d          b          c
#  3          an        aan        aat         as        aan       aaak
#  4          aj        aai         au         ay          o        aab
#  5        aaap          p         ax         ar          q         aw
#  6         aag       aaae         ae       aaad          e         az
#  7         aay       aaab          w          z        aaj         au
#  8         aaf         ay        aac          i        aay       aaad
#  9        aaac       aaac        aau       aaam         as        aat
#  10         ar          q       aaas       aaat          w          j
#  11          e          g       aaan         ak       aaam       aaav
# ...
